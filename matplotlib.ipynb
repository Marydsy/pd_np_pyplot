# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot([1,2,3,4],[1,4,2,16])#绘折线图
plt.show()#显示图像

# %%
plt.plot([1,2,3,4],[1,4,2,16],'o')#散点图
plt.show()#显示图像

# %%
plt.plot([1,2,3,4],[1,4,2,16],'o-')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,2,16],'o-')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,2,16],'^-')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,2,16],'*-')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,2,16],'x-')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,2,16],'d-')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,2,16],'h-')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,2,16],'o--')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,2,16],'v-.')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,2,16],'o-r')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,2,16],'o-g')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,2,16],marker='o')#绘制多条线
plt.plot([1,2,3,4],[4,6,1,0],marker='o',color='g')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,2,16],marker='o',label='A')#绘制多条线
plt.plot([1,2,3,4],[4,6,1,0],marker='o',color='g',label='S&P')
plt.title("Stocks")
plt.xlabel("time")
plt.ylabel("profit")
plt.xlim(0,5)
plt.ylim(0,14)#设置了xy的范围
plt.xticks([0,2,4])#设置刻度
plt.legend()#加注释
plt.show()
